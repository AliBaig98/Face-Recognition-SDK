# %%
from pathlib import Path
import sys

# Project Root
PROJECT_ROOT = Path.cwd().parent

# Add project root to Python Path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# e:\Projects\FaceRecognition

# %%
import sys

print(sys.path[0])
# Out:
# e:\Projects\FaceRecognition

# %%
from pathlib import Path

from src.data.face_detector import FaceDetector

# %%
detector = FaceDetector()

print("Face Detector Loaded Successfully")
# Out:
# FaceDetector initialized
# Face Detector Loaded Successfully

# %%
image_path = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / "lfw_filtered"
    / "George_W_Bush"
    / "George_W_Bush_0001.jpg"
)

print(image_path)
# Out:
# e:\Projects\FaceRecognition\data\processed\lfw_filtered\George_W_Bush\George_W_Bush_0001.jpg

# %%
face = detector.detect_face(image_path)

print(face.shape)
# Out:
# torch.Size([3, 224, 224])

# %%
import matplotlib.pyplot as plt

plt.imshow(face.permute(1, 2, 0))
plt.axis("off")
plt.title("Detected Face")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99609375..0.73046875].
