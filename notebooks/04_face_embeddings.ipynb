# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data.face_detector import FaceDetector
from src.models.face_embedder import FaceEmbedder
# Out:
# face_detector.py is being imported
# Imports completed
# Class created successfully

# %%
detector = FaceDetector()
embedder = FaceEmbedder()
# Out:
# FaceDetector initialized
#   0%|          | 0.00/107M [00:00<?, ?B/s]

# %%
image_path = PROJECT_ROOT / "data" / "processed" / "lfw_filtered" / "George_W_Bush" / "George_W_Bush_0001.jpg"

face = detector.detect_face(image_path)

embedding = embedder.get_embedding(face)

print(embedding.shape)
# Out:
# torch.Size([512])
